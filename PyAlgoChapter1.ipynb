# %%
# %%time
import random
from math import exp, sqrt
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 64.4 µs

# %%
# %%time
s_0 = 100
r = 0.05
T = 1.0
sigma = 0.2

values = []
for _ in range(1000000):
    s_T = s_0 * exp((r - 0.5 * sigma **2) * T +
        sigma * random.gauss(0,1) * sqrt(T))
    values.append(s_T)
# Out:
# CPU times: user 2.85 s, sys: 472 ms, total: 3.32 s
# Wall time: 26.6 s

# %%
# %%time
import numpy as np
s_0 = 100
r = 0.05
T = 1.0
sigma = 0.2
value = s_0 * np.exp((r - 0.5 * sigma ** 2) * T +
                sigma * np.random.standard_normal(100000) * np.sqrt(T))
# Out:
# CPU times: user 136 ms, sys: 24 ms, total: 160 ms
# Wall time: 201 ms

# %%
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()
# %matplotlib inline

# %%
import quandl as q  
d = q.get('BCHAIN/MKPRU')  
d['SMA'] = d['Value'].rolling(100).mean()  
d[d.index > '2013-1-1'].plot(title='BTC/USD exchange rate',
                             figsize=(10, 6));
# Out:
# /root/miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import quandl as q  
d = q.get('LSE/RBS')
d['SMA'] = d['Last Close'].rolling(100).mean() 
d[d.index > '2013-1-1'].plot(title='RBS',
                             figsize=(10, 6));
# Out:
# /root/miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
