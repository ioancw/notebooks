# %%
import string

# %%
def process_line(line, hist):
    line = line.replace('-',' ')
    
    for word in line.split():
        word = word.strip(string.punctuation + string.whitespace)
        word = word.lower() 
        hist[word] = hist.get(word, 0) + 1

# %%
def process_file(filename):
    hist = {}
    fp = open(filename)
    
    for line in fp:
        process_line(line, hist)
    return hist

# %%
def subtract(d1, d2):
    res = {}
    for key in d1:
        if key not in d2:
            res[key] = None
    return res

# %%
def most_common(hist):
    t = []
    for key, value in hist.items():
        t.append((value, key))
    t.sort()
    t.reverse()
    return t

# %%
hist = process_file('/root/emma.txt')
t = most_common(hist)
for freq, word in t[:25]:
    print(word, '\t', freq)
# Out:
# the 	 5353
# to 	 5301
# and 	 4888
# of 	 4396
# a 	 3170
# i 	 2848
# her 	 2443
# it 	 2407
# was 	 2394
# she 	 2334
# in 	 2233
# not 	 2144
# be 	 1982
# you 	 1896
# he 	 1770
# that 	 1765
# had 	 1622
# as 	 1434
# but 	 1361
# for 	 1354
# have 	 1311
# with 	 1260
# is 	 1251
# very 	 1171
# his 	 1143

# %%
words = process_file('/root/words.txt')

# %%
diff = subtract(hist, words)

# %%
diff
# Out:
# {'\ufeffthe': None,
#  'gutenberg': None,
#  'ebook': None,
#  'emma': None,
#  'austen': None,
#  'online': None,
#  'www.gutenberg.org': None,
#  '1994': None,
#  'etext': None,
#  '158': None,
#  'january': None,
#  '21': None,
#  '2010': None,
#  'october': None,
#  '17': None,
#  '2016': None,
#  'utf': None,
#  '8': None,
#  '': None,
#  'i': None,
#  'woodhouse': None,
#  'a': None,
#  'sister’s': None,
#  'remembrance': None,
#  'taylor': None,
#  'mr': None,
#  'woodhouse’s': None,
#  'taylor’s': None,
#  'emma’s': None,
#  'unperceived': None,
#  'weston': None,
#  'unexceptionable': None,
#  'morning’s': None,
#  'unreserve': None,
#  'isabella’s': None,
#  'mrs': None,
#  'valetudinarian': None,
#  'london': None,
#  'november': None,
#  'hartfield': None,
#  'christmas': None,
#  'isabella': None,
#  'highbury': None,
#  'woodhouses': None,
#  'daughter’s': None,
#  '“poor': None,
#  'her!”': None,
#  '“i': None,
#  'own?”': None,
#  '“a': None,
#  'dear.”': None,
#  '“how': None,
#  'soon.”': None,
#  '“my': None,
#  'randalls': None,
#  'far.”': None,
#  '“no': None,
#  'sure.”': None,
#  '“the': None,
#  'james': None,
#  'visit?”': None,
#  '“they': None,
#  'weston’s': None,
#  'hannah': None,
#  'you!”': None,
#  'are.”': None,
#  'knightley': None,
#  'connexions': None,
#  'days’': None,
#  'brunswick': None,
#  'isabella”': None,
#  '“it': None,
#  'walk.”': None,
#  '“not': None,
#  'fire.”': None,
#  '“but': None,
#  'cold.”': None,
#  '“dirty': None,
#  'them.”': None,
#  '“well': None,
#  'wedding.”': None,
#  '“by': None,
#  'most?”': None,
#  '“ah': None,
#  '‘tis': None,
#  'business.”': None,
#  '‘poor': None,
#  'taylor.’': None,
#  'two.”': None,
#  '“especially': None,
#  'creature!”': None,
#  '“that': None,
#  'by.”': None,
#  'indeed,”': None,
#  'troublesome.”': None,
#  'another.”': None,
#  '“emma': None,
#  'her,”': None,
#  'gainer.”': None,
#  '“well,”': None,
#  '“you': None,
#  'day.”': None,
#  '“dear': None,
#  'well,”': None,
#  'for.”': None,
#  'companion,”': None,
#  '“we': None,
#  'married.”': None,
#  '“and': None,
#  'me,”': None,
#  'thing.”': None,
#  'matches.”': None,
#  '“ever': None,
#  'broadway': None,
#  'mitchell’s': None,
#  'making.”': None,
#  '‘success,’”': None,
#  '“success': None,
#  'endeavour': None,
#  'delicately': None,
#  'endeavouring': None,
#  'lady’s': None,
#  '‘i': None,
#  'her,’': None,
#  'said.”': None,
#  '‘success,’': None,
#  'that.”': None,
#  'interference.”': None,
#  'others,”': None,
#  'one’s': None,
#  'grievously.”': None,
#  '“only': None,
#  'elton': None,
#  'service.”': None,
#  '“mr': None,
#  'him.”': None,
#  '“with': None,
#  'time,”': None,
#  'chuse': None,
#  'himself.”': None,
#  'ii': None,
#  'favourite': None,
#  'churchill': None,
#  'yorkshire': None,
#  'connexion': None,
#  'unsuitable': None,
#  'brother’s': None,
#  'enscombe': None,
#  'churchills': None,
#  'years’': None,
#  'mother’s': None,
#  'favourable': None,
#  'portionless': None,
#  'delightful': None,
#  'uncle’s': None,
#  'father’s': None,
#  'deservedly': None,
#  'life.”': None,
#  'hour’s': None,
#  'companionableness': None,
#  'hindrance': None,
#  'taylor,’': None,
#  'stay.”': None,
#  'neighbours': None,
#  'body’s': None,
#  'gentlemanlike': None,
#  'perrys': None,
#  'iii': None,
#  'donwell': None,
#  'unfrequently': None,
#  'westons': None,
#  'goddard': None,
#  'quicksighted': None,
#  'acquirements': None,
#  'goddard’s': None,
#  'prosings': None,
#  'harriet': None,
#  'smith’s': None,
#  'unpolished': None,
#  'betweens': None,
#  '“mrs': None,
#  'serle': None,
#  'you.”': None,
#  'iv': None,
#  'talkativeness': None,
#  'exultation': None,
#  'martin’s': None,
#  '“_two': None,
#  'alderneys': None,
#  'people.”': None,
#  'son’s': None,
#  'shepherd’s': None,
#  'martin!”': None,
#  'about.”': None,
#  'sunday': None,
#  'nash': None,
#  'richardson': None,
#  'her.”': None,
#  'read?”': None,
#  '“oh': None,
#  'wakefield': None,
#  'can.”': None,
#  '“what': None,
#  'martin?”': None,
#  'kingston': None,
#  'often.”': None,
#  'it.”': None,
#  '“to': None,
#  'sight.”': None,
#  'be?”': None,
#  '“he': None,
#  '8th': None,
#  'june': None,
#  '23rd': None,
#  'day’s': None,
#  'odd.”': None,
#  'desirable.”': None,
#  '“six': None,
#  'old!”': None,
#  'yet.”': None,
#  'year.”': None,
#  'gentleman’s': None,
#  '“yes': None,
#  'do.”': None,
#  'farmer’s': None,
#  'education.”': None,
#  'elizabeth': None,
#  'harriet’s': None,
#  'robert': None,
#  'plain?”': None,
#  'gentility.”': None,
#  'sure,”': None,
#  'gentlemen.”': None,
#  'uncouthness': None,
#  'unmodulated': None,
#  'here.”': None,
#  '“certainly': None,
#  'man!”': None,
#  'knightley’s': None,
#  'difference.”': None,
#  'fifty.”': None,
#  '“which': None,
#  'life?”': None,
#  '“there': None,
#  'loss.”': None,
#  '“will': None,
#  'bad.”': None,
#  'us_.”': None,
#  'book”': None,
#  '“in': None,
#  'elton’s': None,
#  'sufferable': None,
#  'day?”': None,
#  'expediency': None,
#  'fastidious': None,
#  'v': None,
#  'weston,”': None,
#  '“of': None,
#  'so?”': None,
#  'good.”': None,
#  'knightley.”': None,
#  '“perhaps': None,
#  'battle.”': None,
#  'know.”': None,
#  'not.”': None,
#  'say,”': None,
#  'wished.”': None,
#  'that_,”': None,
#  'feelingly': None,
#  'i,”': None,
#  '“who': None,
#  'held.”': None,
#  '“yes,”': None,
#  'taylor.”': None,
#  '“thank': None,
#  'weston.”': None,
#  '“why': None,
#  'quarter.”': None,
#  'undesigned': None,
#  'polish.”': None,
#  'night!”': None,
#  'pretty.”': None,
#  '“pretty': None,
#  'figure?”': None,
#  'friend.”': None,
#  '“such': None,
#  'hazle': None,
#  '‘the': None,
#  'health;’': None,
#  'she?”': None,
#  'person,”': None,
#  'harm.”': None,
#  'times.”': None,
#  '“very': None,
#  'me.”': None,
#  'office.”': None,
#  'all,”': None,
#  'to.”': None,
#  'sister.”': None,
#  '“be': None,
#  'satisfied,”': None,
#  '“so': None,
#  'much.”': None,
#  '“she': None,
#  'home.”': None,
#  'present,”': None,
#  '“as': None,
#  'rain?”': None,
#  'vi': None,
#  'required,”': None,
#  'nature.”': None,
#  'little.”': None,
#  '“if': None,
#  'lady,”': None,
#  'before.”': None,
#  '“exactly': None,
#  'hand!”': None,
#  '“great': None,
#  'amiable.”': None,
#  '“did': None,
#  'harriet?”': None,
#  'picture?”': None,
#  'never.”': None,
#  'picture!”': None,
#  '“let': None,
#  'you,”': None,
#  'randalls?”': None,
#  'don’t': None,
#  'catch.”': None,
#  'possession.”': None,
#  '‘why': None,
#  'drawn?’”': None,
#  'persuaded.”': None,
#  'bella': None,
#  'mama’s': None,
#  'that’s': None,
#  'george': None,
#  'last,”': None,
#  'side”': None,
#  'apologised': None,
#  'unfavourable': None,
#  'now.”': None,
#  'wives,”': None,
#  'honourable': None,
#  'mantelpiece': None,
#  'irksomeness': None,
#  'smith’s.”': None,
#  'encourager': None,
#  'complaisance': None,
#  'party.”': None,
#  '“miss': None,
#  'wanted,”': None,
#  '“do': None,
#  'emma,”': None,
#  'indeed!”': None,
#  'pretty,”': None,
#  'tree.”': None,
#  'thing,”': None,
#  'admirable': None,
#  'likeness.”': None,
#  'december': None,
#  '“might': None,
#  'errand.”': None,
#  'world,”': None,
#  'incommoding': None,
#  'incommoded': None,
#  'deposit!”': None,
#  '“this': None,
#  'love,”': None,
#  '‘exactly': None,
#  'so,’': None,
#  'account.”': None,
#  'vii': None,
#  '”': None,
#  '“upon': None,
#  'word,”': None,
#  'letter?”': None,
#  '“pray': None,
#  'i’d': None,
#  'would.”': None,
#  '“is': None,
#  'short?”': None,
#  'letter,”': None,
#  'expected.”': None,
#  'do?”': None,
#  '“yes.”': None,
#  'speedily.”': None,
#  'disappointment.”': None,
#  'then,”': None,
#  '“ought': None,
#  'collect.”': None,
#  'feelings.”': None,
#  'much,”': None,
#  '‘yes,’': None,
#  '‘no’': None,
#  '‘no,’': None,
#  '‘no?’”': None,
#  '“would': None,
#  'of?”': None,
#  'right?”': None,
#  '“perfectly': None,
#  'ever.”': None,
#  'me!”': None,
#  'world.”': None,
#  '“indeed': None,
#  'up.”': None,
#  'more!”': None,
#  'general,”': None,
#  '“at': None,
#  'consideration.”': None,
#  'letter.”': None,
#  'too.”': None,
#  'say?”': None,
#  'again,”': None,
#  '“nor': None,
#  'mill.”': None,
#  'hartfield.”': None,
#  'draper.”': None,
#  '“one': None,
#  'themselves.”': None,
#  '“now': None,
#  'employed,”': None,
#  'name.”': None,
#  'street.”': None,
#  '“has': None,
#  'prepossession': None,
#  'are!”': None,
#  'viii': None,
#  'sir.”': None,
#  'abbey.”': None,
#  'greatcoat': None,
#  'do,”': None,
#  'woman.”': None,
#  'wanting.”': None,
#  '“come,”': None,
#  'girl’s': None,
#  'credit.”': None,
#  'morning?”': None,
#  '“almost': None,
#  'intended.”': None,
#  '“something': None,
#  'perhaps.”': None,
#  '“highbury': None,
#  'wretches!”': None,
#  '“harriet': None,
#  'advantage.”': None,
#  'sort?”': None,
#  'you;”': None,
#  'confidant?”': None,
#  'think,”': None,
#  'obliging,”': None,
#  'him?”': None,
#  'wretch.”': None,
#  'knightley,”': None,
#  'yesterday?”': None,
#  '“certainly,”': None,
#  'you?”': None,
#  'refused.”': None,
#  '“then': None,
#  'about?”': None,
#  '“nonsense': None,
#  'mistaken.”': None,
#  'clearer.”': None,
#  'over.”': None,
#  'equal!”': None,
#  'friend’s': None,
#  '‘even': None,
#  'match.’”': None,
#  'degradation.”': None,
#  'farmer!”': None,
#  'gentlemen’s': None,
#  'martin.”': None,
#  '“whoever': None,
#  'parents,”': None,
#  'encouragement.”': None,
#  'slightingly': None,
#  'chusing': None,
#  'possess.”': None,
#  'sure!”': None,
#  'intimacy,”': None,
#  '“though': None,
#  'master’s': None,
#  'son.”': None,
#  'harriet.”': None,
#  'talked!”': None,
#  '“robert': None,
#  'understand.”': None,
#  'vain.”': None,
#  '“depend': None,
#  'unreserved': None,
#  'apiece.”': None,
#  'well.”': None,
#  '“good': None,
#  'her’s': None,
#  'adversary’s': None,
#  'man’s': None,
#  'woman’s': None,
#  'clayton': None,
#  'agreeableness.”': None,
#  'ix': None,
#  'transcribing': None,
#  'recollect': None,
#  'time.”': None,
#  '“kitty': None,
#  'maid.”': None,
#  'ungallant': None,
#  'destin’d': None,
#  'transcribed': None,
#  'elton?”': None,
#  'woodhouse”': None,
#  '“or': None,
#  'collection,”': None,
#  '“being': None,
#  'moment’s': None,
#  '“take': None,
#  'it,”': None,
#  'own.”': None,
#  '‘pray': None,
#  'glance.’': None,
#  'neptune': None,
#  'out?”': None,
#  '“mermaids': None,
#  'compliment,”': None,
#  'us.”': None,
#  'woodhouse!”': None,
#  'woodhouse,”': None,
#  '“whatever': None,
#  'right,”': None,
#  '‘to': None,
#  '’': None,
#  'me?”': None,
#  'prose.”': None,
#  'place!”': None,
#  '“when': None,
#  'eltons': None,
#  'pre': None,
#  'shakespeare': None,
#  'passage.”': None,
#  'michaelmas': None,
#  'cole.”': None,
#  'twelvemonth': None,
#  'yesterday.”': None,
#  'read.”': None,
#  'certainly.”': None,
#  'short.”': None,
#  'this.”': None,
#  'lines!”': None,
#  '“these': None,
#  'that?”': None,
#  '“leave': None,
#  'book.”': None,
#  'are”': None,
#  'hands,”': None,
#  'charade.”': None,
#  'please.”': None,
#  'fresh?”': None,
#  'in.”': None,
#  '“aye': None,
#  '‘woman': None,
#  'woman.’': None,
#  'emma.”': None,
#  'wink’d': None,
#  'garrick’s': None,
#  'catherine': None,
#  'grandmama': None,
#  'children?”': None,
#  'change?”': None,
#  'here!”': None,
#  'least.”': None,
#  '28th': None,
#  'husband.”': None,
#  'john?”': None,
#  '“henry': None,
#  '‘grandpapa': None,
#  'string?’': None,
#  'grandpapas': None,
#  '“because': None,
#  'way!”': None,
#  'other.”': None,
#  'o’clock': None,
#  'lines.”': None,
#  'doubtingly': None,
#  '“honour,”': None,
#  'smilingly': None,
#  'gallantry.”': None,
#  'saying,”': None,
#  'x': None,
#  'charitable': None,
#  'days.”': None,
#  'now_,”': None,
#  'highbury.”': None,
#  'father.”': None,
#  'all.”': None,
#  'recollecting': None,
#  'so!”': None,
#  'husband’s': None,
#  'father’s.”': None,
#  'bates!”': None,
#  'undistinguishing': None,
#  'unfastidious': None,
#  'unmarried.”': None,
#  'dreadful!”': None,
#  '“never': None,
#  'illiberal': None,
#  'charm.”': None,
#  'old?”': None,
#  'bates’s': None,
#  'acquainted?”': None,
#  'knightleys': None,
#  'fairfax': None,
#  'stomacher': None,
#  'death.”': None,
#  'mind?”': None,
#  'true,”': None,
#  'else.”': None,
#  'over,”': None,
#  'will,”': None,
#  'no,”': None,
#  'ourselves.”': None,
#  'yes,”': None,
#  'this,”': None,
#  'child’s': None,
#  'experienced': None,
#  'yesterday’s': None,
#  'cole’s': None,
#  'stilton': None,
#  'wiltshire': None,
#  'course,”': None,
#  '“any': None,
#  'away!”': None,
#  '“part': None,
#  'gone,”': None,
#  'on.”': None,
#  '“cautious': None,
#  'cautious,”': None,
#  'secure.”': None,
#  'surry': None,
#  'wingfield': None,
#  'ungracious': None,
#  'fidgetiness': None,
#  'unsullied': None,
#  'dear,”': None,
#  'sir,”': None,
#  'tolerably.”': None,
#  'regret.”': None,
#  'both,”': None,
#  'often?”': None,
#  'wish.”': None,
#  'truth.”': None,
#  '“just': None,
#  'be,”': None,
#  'disengaged': None,
#  'satisfied.”': None,
#  'again.”': None,
#  '“me': None,
#  '“are': None,
#  'henry’s': None,
#  'cobham': None,
#  '“where': None,
#  'man?”': None,
#  'not?”': None,
#  'yet,”': None,
#  'lately.”': None,
#  'passes.”': None,
#  '“three': None,
#  'weymouth': None,
#  '‘my': None,
#  'madam,’': None,
#  '‘f': None,
#  'c': None,
#  'churchill.’': None,
#  'perfectly.”': None,
#  'him!”': None,
#  '“nobody': None,
#  'fancy,”': None,
#  'affords.”': None,
#  'xii': None,
#  'aunt’s': None,
#  'unceremoniousness': None,
#  'sauciness': None,
#  'disagree.”': None,
#  'alike.”': None,
#  'discordancies': None,
#  'wrong.”': None,
#  'born.”': None,
#  'nearer?”': None,
#  'nearer_.”': None,
#  'differently.”': None,
#  '“that’s': None,
#  'disappointed.”': None,
#  'so,”': None,
#  'd’ye': None,
#  'george?”': None,
#  '“john': None,
#  'conversable': None,
#  'isabella,”': None,
#  'gruel.”': None,
#  'unpersuadable': None,
#  'discourse': None,
#  'air.”': None,
#  'bella’s': None,
#  'bathing.”': None,
#  'once.”': None,
#  '“come': None,
#  'come,”': None,
#  'sir?”': None,
#  'where.”': None,
#  'ones.”': None,
#  'throat.”': None,
#  'embrocation': None,
#  'wingfield’s': None,
#  'august.”': None,
#  'bates,”': None,
#  'bateses': None,
#  'ago.”': None,
#  'influenza.”': None,
#  'season.”': None,
#  'bad!”': None,
#  'neighbourhood': None,
#  'present.”': None,
#  'ill,”': None,
#  '“middling': None,
#  'chuse.”': None,
#  'brother,”': None,
#  '“about': None,
#  'graham’s': None,
#  'scotland': None,
#  'strong?”': None,
#  'fairfax!”': None,
#  'campbell': None,
#  '“our': None,
#  'age.”': None,
#  'undoubting': None,
#  'philippics': None,
#  '“ah!”': None,
#  'of.”': None,
#  'rumination': None,
#  'end.”': None,
#  'repeatedly.”': None,
#  'cromer': None,
#  'perry.”': None,
#  'forty.”': None,
#  'measure.”': None,
#  'law’s': None,
#  'perry,”': None,
#  'drugs.”': None,
#  '“true': None,
#  'langham': None,
#  'opinion.”': None,
#  'xiii': None,
#  '24th': None,
#  'her?”': None,
#  'tranquillised': None,
#  'night.”': None,
#  'cold,”': None,
#  'works.”': None,
#  'perfect,”': None,
#  'value.”': None,
#  '“me!”': None,
#  'object?”': None,
#  'idea!”': None,
#  'behaviour': None,
#  'more;”': None,
#  'man,”': None,
#  '“must': None,
#  'people’s': None,
#  'administered': None,
#  '“much': None,
#  'better.”': None,
#  '“_my': None,
#  'goddard’s,”': None,
#  '“was': None,
#  '‘not': None,
#  'better’': None,
#  'answer.”': None,
#  'morning.”': None,
#  'heard.”': None,
#  'day!”': None,
#  '“dreadful': None,
#  'moment.”': None,
#  'device,”': None,
#  'unpermitted': None,
#  'see.”': None,
#  '“christmas': None,
#  'weather,”': None,
#  '“quite': None,
#  'se’nnight.”': None,
#  'randalls.”': None,
#  'fires,”': None,
#  'body.”': None,
#  'enjoyment.”': None,
#  'enjoyment,”': None,
#  'xiv': None,
#  'solicitously': None,
#  '“can': None,
#  'insufferable!”': None,
#  'son,”': None,
#  '“frank,”': None,
#  'friends’': None,
#  'substance': None,
#  'fortnight.”': None,
#  'us,”': None,
#  'january.”': None,
#  'yourself.”': None,
#  'frank’s': None,
#  'doing.”': None,
#  'case,”': None,
#  'enscombe.”': None,
#  'temper.”': None,
#  '“for': None,
#  'stands?”': None,
#  'emma!”': None,
#  'caprice?”': None,
#  'churchill,”': None,
#  'them!”': None,
#  'braithwaites': None,
#  'churchills’': None,
#  'sanguine.”': None,
#  'man_‘s': None,
#  'be.”': None,
#  'comes.”': None,
#  'points,”': None,
#  'xv': None,
#  'considerably.”': None,
#  'it?”': None,
#  'aid.”': None,
#  'snow.”': None,
#  'two’s': None,
#  'midnight.”': None,
#  'done?”': None,
#  '“indeed!”': None,
#  'horses.”': None,
#  '“your': None,
#  'go?”': None,
#  '“shall': None,
#  'bell?”': None,
#  'could;”': None,
#  'stept': None,
#  'tete': None,
#  'unequalled': None,
#  'unexampled': None,
#  'mean!”': None,
#  'inebriety': None,
#  'professions.”': None,
#  'heaven!”': None,
#  '“charming': None,
#  'madam,”': None,
#  '“encouragement': None,
#  'xvi': None,
#  'harriet!”': None,
#  '“ready': None,
#  'wit”': None,
#  '“soft': None,
#  'eyes”': None,
#  'indiscreetly': None,
#  'aggrandise': None,
#  'gradations': None,
#  'complaisant': None,
#  'adventuring': None,
#  '“here': None,
#  '“actually': None,
#  'william': None,
#  'coxe': None,
#  'lawyer.”': None,
#  'unmirthful': None,
#  'amiableness': None,
#  'xvii': None,
#  'agreeably': None,
#  'pointedly': None,
#  'solemnity': None,
#  'promptitude': None,
#  'sympathise': None,
#  'non': None,
#  'xviii': None,
#  'period.”': None,
#  'churchill’s': None,
#  'fault,”': None,
#  'proof.”': None,
#  'creature?”': None,
#  'impossible.”': None,
#  'manage.”': None,
#  'churchills.”': None,
#  'pleasure.”': None,
#  'others.”': None,
#  'chuses': None,
#  'manoeuvring': None,
#  '‘every': None,
#  'morrow.’': None,
#  'going.”': None,
#  '“no,”': None,
#  'practicable?”': None,
#  'his.”': None,
#  'conviction.”': None,
#  'him,”': None,
#  'behindhand': None,
#  '‘amiable,’': None,
#  'manners.”': None,
#  'thoughts.”': None,
#  'mine,”': None,
#  'point.”': None,
#  '“prejudiced': None,
#  'prejudiced.”': None,
#  'favour.”': None,
#  'month’s': None,
#  'another,”': None,
#  'poor!”': None,
#  'apartment': None,
#  'beaufet': None,
#  'ceremonies’': None,
#  'writing;’': None,
#  '‘but': None,
#  'morning,’': None,
#  '‘have': None,
#  'honour?’': None,
#  '‘well': None,
#  'says.’”': None,
#  '“have': None,
#  'well?”': None,
#  'kind!”': None,
#  'apologise': None,
#  'hetty': None,
#  'work’': None,
#  'ma’am': None,
#  'well.’”': None,
#  'fairfax’s': None,
#  'kind,”': None,
#  'nobody’s': None,
#  'ma’am,”': None,
#  'jane’s': None,
#  'handwriting?”': None,
#  'soon?”': None,
#  'week.”': None,
#  'friday': None,
#  'saturday': None,
#  'tuesday': None,
#  'wednesday.”': None,
#  'campbells': None,
#  'ireland': None,
#  'dixon': None,
#  'dixon’s': None,
#  'dublin': None,
#  'baly': None,
#  'craig': None,
#  'things.”': None,
#  'campbell.”': None,
#  'dixon!”': None,
#  'bates?”': None,
#  'fairfax.”': None,
#  'course.”': None,
#  '“jane': None,
#  '7th': None,
#  'holyhead': None,
#  'monday': None,
#  '‘bless': None,
#  'ill!’': None,
#  'away,”': None,
#  'lieut': None,
#  'england': None,
#  'campbell’s': None,
#  'novitiate': None,
#  'successless': None,
#  'recantation': None,
#  'handsome!”': None,
#  'dixons': None,
#  'suitableness': None,
#  'handsome?”': None,
#  'man.”': None,
#  'agreeable?”': None,
#  'so.”': None,
#  'information?”': None,
#  'pleasing.”': None,
#  'evening,”': None,
#  '“particularly': None,
#  'grandmother’s': None,
#  'indulgence.”': None,
#  'approved,”': None,
#  '“_that': None,
#  'enough.”': None,
#  'therefore.”': None,
#  'enough;”': None,
#  'reserved.”': None,
#  'honoured.”': None,
#  'evening.”': None,
#  'obtained.”': None,
#  'disappointed,”': None,
#  'heart.”': None,
#  'dear?”': None,
#  'like.”': None,
#  'unwholesome.”': None,
#  '“emma,”': None,
#  '“news': None,
#  'randalls,”': None,
#  '‘shall': None,
#  'kitchen.’': None,
#  '‘oh': None,
#  'dear,’': None,
#  'hawkins': None,
#  'directly.”': None,
#  'pork,”': None,
#  '‘our': None,
#  ...}
